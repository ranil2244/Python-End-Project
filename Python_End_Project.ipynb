# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/myexcel - myexcel.csv.csv')

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # ***Preprocessing:***

# %% [markdown]
# Correct the data in the "height" column by replacing it with random numbers between 150 and 180. Ensure data consistency and integrity before proceeding with analysis. (1 mark)

# %%
df["Height"]=np.random.randint(150,180,len(df))

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     160     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     157     235
# 2     John Holland  Boston Celtics      30       SG   27     173     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     179     203
# 454      Raul Neto       Utah Jazz      25       PG   24     160     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     163     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     156     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
dfc=df.copy()
dfc
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     160     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     157     235
# 2     John Holland  Boston Celtics      30       SG   27     173     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     178     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     179     203
# 454      Raul Neto       Utah Jazz      25       PG   24     160     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     163     256
# 456    Jeff Withey       Utah Jazz      24        C   26     165     231
# 457       Priyanka       Utah Jazz      34        C   25     156     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
dfc.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
dfc.dropna()
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 3      R.J. Hunter  Boston Celtics      28       SG   22     156     185
# 6    Jordan Mickey  Boston Celtics      55       PF   21     151     235
# 7     Kelly Olynyk  Boston Celtics      41        C   25     179     238
# ..             ...             ...     ...      ...  ...     ...     ...
# 451  Chris Johnson       Utah Jazz      23       SF   26     161     206
# 452     Trey Lyles       Utah Jazz      41       PF   20     168     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26     162     203
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     165     231
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
dfc.replace(["", " ", "None", "null"],np.nan,inplace=True)

# %%
dfc.Salary.isnull().sum()
# Out:
# 11

# %%
 # Replace null values in categorical columns with the column mode
dfc['College'] = dfc['College'].fillna(dfc['College'].mode()[0])

# %%
dfc.College.isnull().sum()
# Out:
# 0

# %%
# Replace null values in numerical columns with the column mean
dfc['Salary'] = dfc['Salary'].fillna(dfc['Salary'].mean())

# %%
dfc.Salary.isnull().sum()
# Out:
# 0

# %%
dfc.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
dfc.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.580000e+02
# mean    17.713974   26.934498  164.552402  221.543668  4.833970e+06
# std     15.966837    4.400128    9.029885   26.343200  5.163335e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  157.000000  200.000000  1.100150e+06
# 50%     13.000000   26.000000  165.000000  220.000000  2.862190e+06
# 75%     25.000000   30.000000  172.000000  240.000000  6.323553e+06
# max     99.000000   40.000000  179.000000  307.000000  2.500000e+07

# %%
dfc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   458 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %% [markdown]
#  1.Determine the distribution of Players across each team and calculate the percentage split relative to
#
#  the total number of Players. (2 marks)

# %%
dfc
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2     John Holland  Boston Celtics      30       SG   27     172     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     156     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     161     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     162     203
# 454      Raul Neto       Utah Jazz      25       PG   24     177     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     150     256
# 456    Jeff Withey       Utah Jazz      24        C   26     173     231
# 457       Priyanka       Utah Jazz      34        C   25     165     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
T_count=dfc.groupby("Team")#grouping by team
T_coun

# %%
T_count.size().head()
# Out:
# Team
# Atlanta Hawks        15
# Boston Celtics       15
# Brooklyn Nets        15
# Charlotte Hornets    15
# Chicago Bulls        15
# dtype: int64

# %% [markdown]
# # ***Finding the percentage split***

# %%
t_count=dfc['Team'].value_counts()
total_count=len(dfc)
percentage=round((t_count/total_count)*100,2)  #Calculating the percentage split
percentage.head()
# Out:
# Team
# New Orleans Pelicans    4.15
# Memphis Grizzlies       3.93
# Utah Jazz               3.49
# New York Knicks         3.49
# Milwaukee Bucks         3.49
# Name: count, dtype: float64

# %%
resultantdf= pd.DataFrame({
 'Team': t_count.index,
 'Employee count':t_count.values,
 'Percentage Split':percentage
 })
resultantdf.head()
# Out:
#                                       Team  Employee count  Percentage Split
# Team
# New Orleans Pelicans  New Orleans Pelicans              19              4.15
# Memphis Grizzlies        Memphis Grizzlies              18              3.93
# Utah Jazz                        Utah Jazz              16              3.49
# New York Knicks            New York Knicks              16              3.49
# Milwaukee Bucks            Milwaukee Bucks              16              3.49

# %% [markdown]
# # ***Visualising percentage split of Each Team***

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
plt.bar(resultantdf['Team'] ,resultantdf['Percentage Split'],color='skyblue',edgecolor='black')
plt.title("Team wise Percentage Split")
plt.xlabel('Team')
plt.ylabel('Percentage')
plt.yticks([1,2,3,4,5,])
plt.xticks(rotation=90)
 # Add data labels
for i, v in enumerate(resultantdf['Percentage Split']):
    plt.text(i, v + 0.5, str(v), ha='center',rotation=90,fontsize=7)
plt.show()

# %% [markdown]
# #Inference : "New Orleans Pelicans" has the highest percentage
# #of players.

# %%
# plt.figure(figsize=(8,6))
 # plt.pie(resultantdf['Percentage Split'],labels=resultantdf['Team'],autopct='%1.0f
 # plt.show()

# %% [markdown]
# # ***2.Segregate Players based on their positions.(2marks)***

# %%
dfc.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     168     235
# 2   John Holland  Boston Celtics      30       SG   27     172     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     156     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     161     231
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.833970e+06
# 3      Georgia State  1.148640e+06
# 4           Kentucky  5.000000e+06

# %%
P_count=dfc['Position'].value_counts()
P_count
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
Position=pd.DataFrame({
 'Position':P_count.index,
 'Number of players':P_count.values
 })
Position
# Out:
#   Position  Number of players
# 0       SG                102
# 1       PF                100
# 2       PG                 92
# 3       SF                 85
# 4        C                 79

# %%
plt.bar(Position['Position'] ,Position['Number of players'],color='r')
plt.title("Position Wise Players Distribution")
plt.xlabel('Position')
plt.ylabel('Number of players')
plt.show()

# %% [markdown]
# # **inference: position'SG'haa thehighest number of players and position'C' has the lowest number of players**

# %% [markdown]
# # ***3.identify the prodominant age group amoung the players.(2.mark)***

# %%
dfc.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     160     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     157     235
# 2   John Holland  Boston Celtics      30       SG   27     173     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     164     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     178     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
Agegroup=dfc.groupby('Age')
Agegroup

# %%
Agegroup.size()
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    46
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# dtype: int64

# %% [markdown]
# # **Identify the prodominant age group**

# %%
Agegroup.size().max() # Predominant Age
# Out:
# 47

# %%
Age_group=pd.DataFrame({
 'Name':dfc['Name'],
 'Age':dfc['Age']
 })
Age_group.head()

# %% [markdown]
# # **Creating group of age**

# %%
bins=[10,15,20,25,30,35,40,45,50]
labels=['10-15','15-20','20-25','25-30','30-35','35-40','40-45','45-50']
Age_group['Age_Group'] = pd.cut(Age_group['Age'], bins=bins, labels=labels, right=False)
Age_group
# Out:
#               Name  Age Age_Group
# 0    Avery Bradley   25     25-30
# 1      Jae Crowder   25     25-30
# 2     John Holland   27     25-30
# 3      R.J. Hunter   22     20-25
# 4    Jonas Jerebko   29     25-30
# ..             ...  ...       ...
# 453   Shelvin Mack   26     25-30
# 454      Raul Neto   24     20-25
# 455   Tibor Pleiss   26     25-30
# 456    Jeff Withey   26     25-30
# 457       Priyanka   25     25-30
#
# [458 rows x 3 columns]

# %%
A_group=Age_group.groupby('Age_Group')
A_group
# Out:
# <ipython-input-20-2f66573453c4>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   A_group=Age_group.groupby('Age_Group')

# %%
A_group.size()# finding the predominant age group
# Out:
# Age_Group
# 10-15      0
# 15-20      2
# 20-25    152
# 25-30    182
# 30-35     90
# 35-40     29
# 40-45      3
# 45-50      0
# dtype: int64

# %%
sns.histplot(Age_group['Age_Group'], bins=9, color='lightgreen', edgecolor='black')
plt.title("Predominant Age group among Players")
plt.show()

# %% [markdown]
# # **Found that "25 to 30" is the prodominant age group**

# %% [markdown]
# # ***4.discovery which team andposition have the highest salary expenditure.(2.mark)***

# %% [markdown]
# Finding the position wise mean of salaries to find which
#  position has highest salary expenditure.

# %%
Position=dfc.groupby('Position')['Salary'].mean()
Position
# Out:
# Position
# C     5.903511e+06
# PF    4.562483e+06
# PG    5.077829e+06
# SF    4.857393e+06
# SG    4.009861e+06
# Name: Salary, dtype: float64

# %%
Position.max()
# Out:
# 5903510.53164557

# %%
dfc['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
plt.bar(Position.index,Position.values,color='green')
plt.xlabel('Position')
plt.ylabel('Average Salary (In Ten lakhs)')
plt.title('Average Salary by Position')
plt.show()

# %% [markdown]
# # **Inference : Highest salary is for 'C' position**

# %%
team=dfc.groupby('Team')['Salary'].mean()
team
# Out:
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# Miami Heat                6.347359e+06
# Milwaukee Bucks           4.350220e+06
# Minnesota Timberwolves    4.593054e+06
# New Orleans Pelicans      4.355304e+06
# New York Knicks           4.581494e+06
# Oklahoma City Thunder     6.251020e+06
# Orlando Magic             4.297248e+06
# Philadelphia 76ers        2.213778e+06
# Phoenix Suns              4.229676e+06
# ...

# %%
team_sorted = team.sort_values(ascending=False)
team_sorted
# Out:
# Team
# Cleveland Cavaliers       7.642049e+06
# Miami Heat                6.347359e+06
# Los Angeles Clippers      6.323643e+06
# Oklahoma City Thunder     6.251020e+06
# Golden State Warriors     5.924600e+06
# Chicago Bulls             5.785559e+06
# San Antonio Spurs         5.629516e+06
# Memphis Grizzlies         5.467920e+06
# Charlotte Hornets         5.222728e+06
# Washington Wizards        5.088576e+06
# Houston Rockets           5.018868e+06
# Atlanta Hawks             4.860197e+06
# Los Angeles Lakers        4.784695e+06
# Sacramento Kings          4.778911e+06
# Dallas Mavericks          4.746582e+06
# Toronto Raptors           4.741174e+06
# Minnesota Timberwolves    4.593054e+06
# New York Knicks           4.581494e+06
# Detroit Pistons           4.477884e+06
# Indiana Pacers            4.450122e+06
# New Orleans Pelicans      4.355304e+06
# Milwaukee Bucks           4.350220e+06
# Orlando Magic             4.297248e+06
# Denver Nuggets            4.294424e+06
# ...

# %%
plt.bar(team.index,team.values,color='lightpink')
plt.xlabel('Team')
plt.ylabel('Average Salary (In Ten lakhs)')
plt.title('Average Salary by Team')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # **Inference : Team 'Cleveland Cavaliers ' have the highest salary.**

# %% [markdown]
# # ***5.Inestigate if there's any correlation between age and salarynand represent it visually.(2.mark)***

# %%
# Pearson correlation (default)
correlation = dfc['Age'].corr(df['Salary'])
print(f"Pearson Correlation: {correlation:.2f}")
# Out:
# Pearson Correlation: 0.21

# %% [markdown]
# # inference: The correlation between Age and salaryis slightly positive, that is When age increase the salary will increasein a slightly manner

# %%
# Scatter plot
sns.scatterplot(x='Age', y='Salary', data=dfc)
plt.title("Scatter Plot of Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# # *Detailed Analysis*

# %% [markdown]
#  :General Trend: The plot still suggests a weak positive correlation, as the salaries tend to
#  slightly increase with age, particularly between ages 20 to 30.

# %% [markdown]
# :Clusters: A significant number of data points are clustered between ages 20 and 30, with
#  salaries mostly below 1e7. There are fewer data points for individuals above age 35,
#  indicating either fewer data entries or less representation in the dataset.

# %% [markdown]
# :Outliers: Some individuals, especially between ages 25 and 30, have exceptionally high
#  salaries (above 2e7). These outliers could be key executives, entrepreneurs, or anomalies
#  in the data.

# %% [markdown]
# :Plateau or Decline: For ages above 30, the data points seem to flatten or spread more,
#  with salaries not increasing significantly or even decreasing in some cases.

# %% [markdown]
# # *A heat map also ploting for much more relations*

# %%
numeric_df = dfc.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(),annot=True, cmap='coolwarm')
plt.title('Correlation map')
plt.show()

# %% [markdown]
# # **Different correlation is visible here.**

# %% [markdown]
# # **Inferences :**

# %% [markdown]
#  "New Orleans Pelicans" has the highest percentage of players.

# %% [markdown]
# :Position 'SG' has the highest number of players and Position 'C' has the lowest number
#  of players.

# %% [markdown]
# :Found that "25 to 30 " is the predominant age group.

# %% [markdown]
# :Highest salary is for 'C' position .

# %% [markdown]
# :The correlation between Age and Salary is slightly positive, that is When age increases
#  the salary will increase in a slight manner.

# %% [markdown]
# :Team 'Cleveland Cavaliers ' have the highest salary.
